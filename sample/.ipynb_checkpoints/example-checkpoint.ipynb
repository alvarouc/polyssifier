# %%
import warnings
warnings.filterwarnings('ignore')
from sklearn import datasets
from polyssifier import Poly
import numpy as np
import pandas as pd
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt 

# %matplotlib inline
data, label = make_moons(n_samples=1000, noise=0.3)
print(data.shape)
print(label.shape)

plt.plot(data[label==0,0], data[label==0,1],'.');
plt.plot(data[label==1,0], data[label==1,1],'r.');
# Out:
# (1000, 2)
# (1000,)

# %%
# single class example
pol = Poly(data,label, n_folds=5, exclude=['Multilayer Perceptron'], verbose =1)

scores= pol.run()
#pol.plot()
# Out:
# INFO:polyssifier.simpler:Running Nearest Neighbors
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    1.1s finished
# INFO:polyssifier.simpler:Running RBF SVM
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   12.6s finished
# INFO:polyssifier.simpler:Running Random Forest
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    5.3s finished
# INFO:polyssifier.simpler:Running Linear SVM
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    2.4s finished
# INFO:polyssifier.simpler:Running Logistic Regression
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    1.1s finished
# INFO:polyssifier.simpler:Running Naive Bayes
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s finished
# INFO:polyssifier.simpler:Running Decision Tree
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s finished
# INFO:polyssifier.simpler:Running Voting
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  1.8min finished

# %%
pol.plot()
# Out:
#    Decision Tree  Linear SVM  Logistic Regression  Naive Bayes  \
# 0       0.869948    0.874746             0.874746     0.884859
# 1       0.824785    0.844810             0.844810     0.844903
# 2       0.890000    0.839936             0.844965     0.839936
# 3       0.849865    0.834996             0.840000     0.834996
# 4       0.879952    0.894997             0.899990     0.894997
#
#    Nearest Neighbors   RBF SVM  Random Forest    Voting
# 0           0.909774  0.929937       0.904883  0.919928
# 1           0.894934  0.910000       0.874972  0.904998
# 2           0.899990  0.904941       0.889901  0.889989
# 3           0.894554  0.884859       0.919928  0.894976
# 4           0.949980  0.939976       0.930000  0.930000
