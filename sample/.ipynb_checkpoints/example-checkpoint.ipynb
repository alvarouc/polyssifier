# %%
from sklearn import datasets
from polyssifier2 import Poly
import numpy as np
import pandas as pd
from pandas.tools.plotting import scatter_matrix
import seaborn as sns
# %matplotlib inline
iris = sns.load_dataset("iris")
sns.pairplot(iris, hue="species");
X = np.array(iris)[:,:4].astype('float')
y = np.array(iris)[:,-1]
#y = pd.Factor(iris['species']).labels
#X = iris.drop('species').get_values()
#y

# %%
# single class example
mask= np.logical_or(y=='versicolor', y=='virginica')
x2 = X[mask,:]
y2 = ((y[mask] =='versicolor')*1).ravel()
pol = Poly(x2,y2, n_folds=5)
pol.run()
pol.plot()
# Out:
# INFO:polyssifier2.poly:Running Decision Tree...
# INFO:polyssifier2.poly:Working on fold 1
# INFO:polyssifier2.poly:train/test AUC: 100.0/100.0]
# INFO:polyssifier2.poly:Working on fold 2
# INFO:polyssifier2.poly:train/test AUC: 100.0/90.9]
# INFO:polyssifier2.poly:Working on fold 3
# INFO:polyssifier2.poly:train/test AUC: 100.0/100.0]
# INFO:polyssifier2.poly:Working on fold 4
# INFO:polyssifier2.poly:train/test AUC: 100.0/90.9]
# INFO:polyssifier2.poly:Working on fold 5
# INFO:polyssifier2.poly:train/test AUC: 100.0/75.0]
# INFO:polyssifier2.poly:Running Linear SVM...
# INFO:polyssifier2.poly:Working on fold 1
# INFO:polyssifier2.poly:train/test AUC: 95.6/100.0]
# INFO:polyssifier2.poly:Working on fold 2
# INFO:polyssifier2.poly:train/test AUC: 97.7/100.0]
# INFO:polyssifier2.poly:Working on fold 3
# INFO:polyssifier2.poly:train/test AUC: 97.7/100.0]
# INFO:polyssifier2.poly:Working on fold 4
# INFO:polyssifier2.poly:train/test AUC: 96.6/100.0]
# ...

# %%
pol = Poly(X,y, n_folds=5)
pol.run()
pol.plot()
# Out:
# INFO:polyssifier2.poly:Running Decision Tree...
# INFO:polyssifier2.poly:Working on fold 1
# INFO:polyssifier2.poly:train/test AUC: 100.0/100.0]
# INFO:polyssifier2.poly:Working on fold 2
# INFO:polyssifier2.poly:train/test AUC: 100.0/93.3]
# INFO:polyssifier2.poly:Working on fold 3
# INFO:polyssifier2.poly:train/test AUC: 100.0/100.0]
# INFO:polyssifier2.poly:Working on fold 4
# INFO:polyssifier2.poly:train/test AUC: 100.0/100.0]
# INFO:polyssifier2.poly:Working on fold 5
# INFO:polyssifier2.poly:train/test AUC: 100.0/93.3]
# INFO:polyssifier2.poly:Running Linear SVM...
# INFO:polyssifier2.poly:Working on fold 1
# INFO:polyssifier2.poly:train/test AUC: 97.0/100.0]
# INFO:polyssifier2.poly:Working on fold 2
# INFO:polyssifier2.poly:train/test AUC: 98.5/100.0]
# INFO:polyssifier2.poly:Working on fold 3
# INFO:polyssifier2.poly:train/test AUC: 98.5/100.0]
# INFO:polyssifier2.poly:Working on fold 4
# INFO:polyssifier2.poly:train/test AUC: 97.8/100.0]
# ...
